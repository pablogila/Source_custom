# %%
import mcstasscript as ms
# Reset previous definitions
try:
    del(instrument, source, tof_monitor, l_monitor, data)
except:
    pass

# %%
name = 'test_PSI_Source_gen'
instrument = ms.McStas_instr(
    name,
    author = 'Pablo Gila-Herranz',
    origin = 'Materials Physics Center (CFM-MPC), CSIC-UPV/EHU',
    ncount = 1e8,
    mpi = 4,
    output_path = f'_simulations/{name}',
    input_path = '_simulations',
    )

# %%
instrument.available_components('monitors')
instrument.component_help('Source_gen')
instrument.component_help('TOF_monitor')
instrument.component_help('L_monitor')
# Out:
# Here are all components in the monitors category.
#  Brilliance_monitor     Flex_monitor_1D         PSD_monitor_4PI        Res_monitor
#  Cyl_monitor            Flex_monitor_2D         PSD_monitor_4PI_spin   Sqq_w_monitor
#  Cyl_monitor_PSD        Flex_monitor_3D         PSD_monitor_TOF        Sqw_monitor
#  Cyl_monitor_TOF        L_monitor               PSD_monitor_psf        TOF2E_monitor
#  Div1D_monitor          MeanPolLambda_monitor   PSD_monitor_psf_eff    TOF2Q_cylPSD_monitor
#  DivLambda_monitor      Monitor                 PSDcyl_monitor         TOFLambda_monitor
#  DivPos_monitor         Monitor_4PI             PSDlin_diff_monitor    TOFRes_monitor
#  Divergence_monitor     Monitor_nD              PSDlin_monitor         TOF_PSD_monitor_rad
#  EPSD_monitor           Monitor_nD_noacc        PolLambda_monitor      TOF_cylPSD_monitor
#  E_monitor              PSD_TOF_monitor         Pol_monitor            TOF_monitor
#  Event_monitor_simple   PSD_monitor             PreMonitor_nD          TOFlog_monitor
#  ___ Help Source_gen ___________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# flux_file = "NULL" [str] // Name of a two columns [lambda flux] text file that contains the wavelength
#                             distribution of the flux in <b>either</b> [1/(s*cm**2*st)] <b>or</b> [1/(s*cm**2*st*AA)]
#                             (see flux_file_perAA flag) Comments (#) and further columns are ignored. Format is
#                             compatible with McStas/PGPLOT wavelength monitor files. When specified, temperature and
#                             intensity values are ignored.
# xdiv_file = "NULL" [str] // Name of the x-horiz. divergence distribution file, given as a free format text matrix,
#                             preceeded with a line '# xylimits
# ydiv_file = "NULL" [str] // Name of the y-vert. divergence distribution file, given as a free format text matrix,
#                             preceeded with a line '# xylimits
# radius = 0.0 [m] // Radius of circle in (x,y,0) plane where neutrons are generated. You may also use 'yheight' and
#                     'xwidth' for a square source
# dist = 0.0 [m] // Distance to target along z axis.
# focus_xw = 0.045 [m] // Width of target.
# focus_yh = 0.12 [m] // Height of target.
# focus_aw = 0.0 [deg] // maximal (uniform) horz. width divergence
# focus_ah = 0.0 [deg] // maximal (uniform) vert. height divergence
# E0 = 0.0 [meV] // Mean energy of neutrons.
# dE = 0.0 [meV] // Energy spread of neutrons, half width.
# lambda0 = 0.0 [AA] // Mean wavelength of neutrons.
# dlambda = 0.0 [AA] // Wavelength spread of neutrons,half width
# I1 = 1.0 [1/(cm**2*sr)] // Source flux per solid angle, area and Angstrom if I1=0, the source emits 1 in 4*PI
#                            whole space.
# yheight = 0.1 [m] // Source y-height, then does not use radius parameter
# xwidth = 0.1 [m] // Source x-width, then does not use radius parameter
# verbose = 0.0 [0/1] // display info about the source. -1 unactivate source.
# T1 = 0.0 [K] // Temperature of the Maxwellian source, 0=none
# flux_file_perAA = 0.0 [1] // When true (1), indicates that flux file data is already per Aangstroem. If false,
#                              file data is per wavelength bin.
# flux_file_log = 0.0 [1] // When true, will transform the flux table in log scale to improve the sampling.
# Lmin = 0.0 [AA] // Minimum wavelength of neutrons
# Lmax = 0.0 [AA] // Maximum wavelength of neutrons
# Emin = 0.0 [meV] // Minimum energy of neutrons
# Emax = 0.0 [meV] // Maximum energy of neutrons
# T2 = 0.0 [K] // Second Maxwellian source Temperature, 0=none
# I2 = 0.0 [1/(cm**2*sr)] // Second Maxwellian Source flux
# T3 = 0.0 [K] // Third Maxwellian source Temperature, 0=none
# I3 = 0.0 [1/(cm**2*sr)] // Third Maxwellian Source flux
# zdepth = 0.0 [m] // Source z-zdepth, not anymore flat
# target_index = 1 [1] // relative index of component to focus at, e.g. next is +1 this is used to compute 'dist'
#                         automatically.
# ------------------------------------------------------------------------------------------------------------------------
#  ___ Help TOF_monitor __________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# nt = 20 [1] // Number of time bins
# filename = 0 [string] // Name of file in which to store the detector image
# xmin = -0.05 [m] // Lower x bound of detector opening
# xmax = 0.05 [m] // Upper x bound of detector opening
# ymin = -0.05 [m] // Lower y bound of detector opening
# ymax = 0.05 [m] // Upper y bound of detector opening
# xwidth = 0.0 [m] // Width of detector. Overrides xmin, xmax
# yheight = 0.0 [m] // Height of detector. Overrides ymin, ymax
# tmin = 0.0 [mu-s] // Lower time limit
# tmax = 0.0 [mu-s] // Upper time limit
# dt = 1.0 [mu-s] // Length of each time bin
# restore_neutron = 0 [1] // If set, the monitor does not influence the neutron state
# nowritefile = 0 [1] // If set, monitor will skip writing to disk
# ------------------------------------------------------------------------------------------------------------------------
#  ___ Help L_monitor ____________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# nL = 20 [1] // Number of wavelength channels
# filename = 0 [string] // Name of file in which to store the detector image
# nowritefile = 0 [1] // If set, monitor will skip writing to disk
# xmin = -0.05 [m] // Lower x bound of detector opening
# xmax = 0.05 [m] // Upper x bound of detector opening
# ymin = -0.05 [m] // Lower y bound of detector opening
# ymax = 0.05 [m] // Upper y bound of detector opening
# xwidth = 0.0 [m] // Width of detector. Overrides xmin, xmax.
# yheight = 0.0 [m] // Height of detector. Overrides ymin, ymax.
# Lmin [AA] // Minimum wavelength to detect
# Lmax [AA] // Maximum wavelength to detect
# restore_neutron = 0 [1] // If set, the monitor does not influence the neutron state
# ------------------------------------------------------------------------------------------------------------------------

# %%
source = instrument.add_component("source", "Source_gen")
tof_monitor = instrument.add_component("TOF_monitor", "TOF_monitor")
l_monitor = instrument.add_component("L_monitor", "L_monitor")

# %%
# Parameters from the ESS butterfly moderator for testing purposes

xw = 0.1
yh = 0.1
dist = 10.0
Lmin = 0.2
Lmax = 10

source.set_parameters(
    xwidth = xw,
    yheight = yh,
    target_index = 1,
    focus_xw = xw,
    focus_yh = yh,
    Lmin = Lmin,
    Lmax = Lmax,
    T1 = 296.2,
    I1 = 8.5e+11,
    T2 = 40.68,
    I2 = 5.2e+11,
    )
source.set_AT([0,0,0])

tof_monitor.set_parameters(
    nt = 100,
    xwidth = xw,
    yheight = yh,
    tmin = 0.0,
    tmax = 1.0e+6,
    restore_neutron = 1,
    )
tof_monitor.set_AT(dist)

l_monitor.set_parameters(
    nL = 100,
    xwidth = xw,
    yheight = yh,
    Lmin = Lmin,
    Lmax = Lmax,
    restore_neutron = 1,
    )
l_monitor.set_AT(dist)

# %%
data = instrument.backengine()
# Out:
# ---- Found 1 places in McStas output with keyword 'error'.
#
# [slimbook:21953] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# INFO: Placing instr file copy test_Source_custom.instr in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_Source_custom_23
# INFO: Placing generated c-code copy test_Source_custom.c in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_Source_custom_23
#
# ----------------------------------------------------------------------
#
# INFO: Using directory: "/home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_Source_custom_23"
# INFO: Regenerating c-file: test_Source_custom.c
# CFLAGS=
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# INFO: Recompiling: ./test_Source_custom.out
# INFO: ===
# --------------------------------------------------------------------------
# WARNING: Linux kernel CMA support was requested via the
# btl_vader_single_copy_mechanism MCA variable, but CMA support is
# not available due to restrictive ptrace settings.
#
# The vader shared memory BTL will fall back on another single-copy
# mechanism if one is available. This may result in lower performance.
#
#   Local host: slimbook
# --------------------------------------------------------------------------
# Simulation 'test_Source_custom' (test_Source_custom.instr): running on 4 nodes (master is 'slimbook', MPI version 3.1).
# Instrument parameters for test_Source_custom (test_Source_custom.instr)
# *** TRACE end ***
# Detector: TOF_monitor_I=1.35751e+10 TOF_monitor_ERR=2.25204e+06 TOF_monitor_N=1e+08 "TOF_monitor.dat"
# Detector: L_monitor_I=1.35751e+10 L_monitor_ERR=2.25204e+06 L_monitor_N=1e+08 "L_monitor.dat"
# [slimbook:21953] 3 more processes have sent help message help-btl-vader.txt / cma-permission-denied
# [slimbook:21953] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# INFO: Placing instr file copy test_Source_custom.instr in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_Source_custom_23
# INFO: Placing generated c-code copy test_Source_custom.c in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_Source_custom_23

# %%
ms.make_sub_plot(data, log = False)

# %%
import mcstasscript as ms
# Reset previous definitions
try:
    del(instrument, source, tof_monitor, l_monitor, data)
except:
    pass

# %%
name = 'test_HBS_thermal_Source_custom'
instrument = ms.McStas_instr(
    name,
    author = 'Pablo Gila-Herranz',
    origin = 'Materials Physics Center (CFM-MPC), CSIC-UPV/EHU',
    ncount = 1e8,
    mpi = 4,
    output_path = f'_simulations/{name}',
    input_path = '_simulations',
    )

# %%
instrument.available_components('monitors')
instrument.component_help('Source_custom')
instrument.component_help('TOF_monitor')
instrument.component_help('L_monitor')
instrument.component_help('TOFLambda_monitor')
# Out:
# Here are all components in the monitors category.
#  Brilliance_monitor     Flex_monitor_1D         PSD_monitor_4PI        Res_monitor
#  Cyl_monitor            Flex_monitor_2D         PSD_monitor_4PI_spin   Sqq_w_monitor
#  Cyl_monitor_PSD        Flex_monitor_3D         PSD_monitor_TOF        Sqw_monitor
#  Cyl_monitor_TOF        L_monitor               PSD_monitor_psf        TOF2E_monitor
#  Div1D_monitor          MeanPolLambda_monitor   PSD_monitor_psf_eff    TOF2Q_cylPSD_monitor
#  DivLambda_monitor      Monitor                 PSDcyl_monitor         TOFLambda_monitor
#  DivPos_monitor         Monitor_4PI             PSDlin_diff_monitor    TOFRes_monitor
#  Divergence_monitor     Monitor_nD              PSDlin_monitor         TOF_PSD_monitor_rad
#  EPSD_monitor           Monitor_nD_noacc        PolLambda_monitor      TOF_cylPSD_monitor
#  E_monitor              PSD_TOF_monitor         Pol_monitor            TOF_monitor
#  Event_monitor_simple   PSD_monitor             PreMonitor_nD          TOFlog_monitor
#  ___ Help Source_custom ________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# target_index = 1 [1] // Relative index of component to focus at, e.g. next is +1 (used to compute 'dist'
#                         automatically)
# dist = 0.0 [m] // Distance from the source to the target
# focus_xw = 0.02 [m] // Width of the target (focusing rectangle)
# focus_yh = 0.02 [m] // Height of the target (focusing rectangle)
# xwidth = 0.0 [m] // Width of the source
# yheight = 0.0 [m] // Height of the source
# radius = 0.01 [m] // Outer radius of the source (ignored if xwidth and yheight are set)
# r_i = 0.0 [m] // Radius of a central circle at temperature T1, sorrounded by a ring at temperature T2 (ignored by
#                  default)
# Lmin [AA] // Lower edge of the wavelength distribution
# Lmax [AA] // Upper edge of the wavelength distribution
# freq [Hz] // Frequency of pulses
# t_pulse [s] // Proton pulse length
# tmax_multiplier = 3.0 [1] // Defined maximum emission time at moderator (tmax = tmax_multiplier * t_pulse); 1 for
#                              continuous sources
# n_pulses = 1 [1] // Number of pulses to be simulated (ignored for continuous sources)
# T1 = 0.0 [K] // Temperature of the 1st Maxwellian distribution; for r_i > 0 it is only used for the central radii
#                 r < r_i
# I1 = 0.0 [1/(cm^2 sr s AA)] // Flux per solid angle of the 1st Maxwellian distribution (integrated over the whole
#                                wavelength range)
# tau1 = 0.000125 [s] // Pulse decay time constant of the 1st Maxwellian distribution
# T2 = 0.0 [K] // Temperature of the 2nd Maxwellian distribution (0 to disable); for r_i > 0 it is only used for the
#                 external ring r > r_i
# I2 = 0.0 [1/(cm^2 sr s AA)] // Flux per solid angle of the 2nd Maxwellian distribution
# tau2 = 0.000125 [s] // Pulse decay time constant of the 2nd Maxwellian distribution
# T3 = 0.0 [K] // Temperature of the 3rd Maxwellian distribution (0 to disable)
# I3 = 0.0 [1/(cm^2 sr s AA)] // Flux per solid angle of the 3rd Maxwellian distribution
# tau3 = 0.000125 [s] // Pulse decay time constant of the 3rd Maxwellian distribution
# n_mod = 1.0 [1] // Ratio of pulse decay constant to pulse ascend constant of moderated neutrons (n = tau_decay /
#                    tau_ascend)
# I_um = 0.0 [1/(cm^2 sr s AA)] // Flux per solid angle for the under-moderated neutrons
# tau_um = 1.2e-05 [s] // Pulse decay time constant of under-moderated neutrons
# n_um = 1.0 [1] // Ratio of pulse decay constant to pulse ascend constant of under-moderated neutrons
# chi_um = 2.5 [1/AA] // Factor for the wavelength dependence of under-moderated neutrons
# kap_um = 2.2 [1] // Scaling factor for the flux of under-moderated neutrons
# ------------------------------------------------------------------------------------------------------------------------
#  ___ Help TOF_monitor __________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# nt = 20 [1] // Number of time bins
# filename = 0 [string] // Name of file in which to store the detector image
# xmin = -0.05 [m] // Lower x bound of detector opening
# xmax = 0.05 [m] // Upper x bound of detector opening
# ymin = -0.05 [m] // Lower y bound of detector opening
# ymax = 0.05 [m] // Upper y bound of detector opening
# xwidth = 0.0 [m] // Width of detector. Overrides xmin, xmax
# yheight = 0.0 [m] // Height of detector. Overrides ymin, ymax
# tmin = 0.0 [mu-s] // Lower time limit
# tmax = 0.0 [mu-s] // Upper time limit
# dt = 1.0 [mu-s] // Length of each time bin
# restore_neutron = 0 [1] // If set, the monitor does not influence the neutron state
# nowritefile = 0 [1] // If set, monitor will skip writing to disk
# ------------------------------------------------------------------------------------------------------------------------
#  ___ Help L_monitor ____________________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# nL = 20 [1] // Number of wavelength channels
# filename = 0 [string] // Name of file in which to store the detector image
# nowritefile = 0 [1] // If set, monitor will skip writing to disk
# xmin = -0.05 [m] // Lower x bound of detector opening
# xmax = 0.05 [m] // Upper x bound of detector opening
# ymin = -0.05 [m] // Lower y bound of detector opening
# ymax = 0.05 [m] // Upper y bound of detector opening
# xwidth = 0.0 [m] // Width of detector. Overrides xmin, xmax.
# yheight = 0.0 [m] // Height of detector. Overrides ymin, ymax.
# Lmin [AA] // Minimum wavelength to detect
# Lmax [AA] // Maximum wavelength to detect
# restore_neutron = 0 [1] // If set, the monitor does not influence the neutron state
# ------------------------------------------------------------------------------------------------------------------------
#  ___ Help TOFLambda_monitor ____________________________________________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# nowritefile = 0 [1] // If set, monitor will skip writing to disk
# nL = 20 [1] // Number of bins in wavelength
# nt = 128 [1] // Number of bins in TOF
# tmin [us] // Minimum time
# tmax [us] // Maximum time
# filename = 0 [string] // Name of file in which to store the detector image
# xmin = -0.05 [m] // Lower x bound of detector opening
# xmax = 0.05 [m] // Upper x bound of detector opening
# ymin = -0.05 [m] // Lower y bound of detector opening
# ymax = 0.05 [m] // Upper y bound of detector opening
# xwidth = 0.0 [m] // Width/diameter of detector (x). Overrides xmin, xmax
# yheight = 0.0 [m] // Height of detector (y). Overrides ymin, ymax
# Lmin [AA] // Minimum wavelength detected
# Lmax [AA] // Maximum wavelength detected
# restore_neutron = 0 [1] // If set, the monitor does not influence the neutron state
# ------------------------------------------------------------------------------------------------------------------------

# %%
source = instrument.add_component("source", "Source_custom")
tof_monitor = instrument.add_component("TOF_monitor", "TOF_monitor")
l_monitor = instrument.add_component("L_monitor", "L_monitor")

# %%
xw = 0.04
yh = 0.04
dist = 10
Lmin = 0.2
Lmax = 20
freq = 24

source.set_parameters(
    xwidth = xw,
    yheight = yh,
    target_index = 1,
    focus_xw = xw,
    focus_yh = yh,
    Lmin = Lmin,
    Lmax = Lmax,
    freq = freq,
    t_pulse = 0.016,
    T1 = 325.0,
    I1 = 0.68e+12,
    tau1 = 0.000125,
    n_mod = 1,
    I_um = 2.47e+10,
    n_um = 1,
    chi_um = 2.5,
    tmax_multiplier = 3,
    n_pulses = 1.0,
    )
source.set_AT([0,0,0])

tof_monitor.set_parameters(
    nt = 100,
    xwidth = xw,
    yheight = yh,
    tmin = 0.0,
    tmax = 0.04e+6,
    restore_neutron = 1,
    )
tof_monitor.set_AT(dist)

l_monitor.set_parameters(
    nL = 100,
    xwidth = xw,
    yheight = yh,
    Lmin = Lmin,
    Lmax = Lmax,
    restore_neutron = 1,
    )
l_monitor.set_AT(dist)

# %%
data = instrument.backengine()
# Out:
# ---- Found 1 places in McStas output with keyword 'error'.
#
# [slimbook:27831] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# *** TRACE end ***
# Detector: TOF_monitor_I=1.82308e+08 TOF_monitor_ERR=105494 TOF_monitor_N=3.24599e+07 "TOF_monitor.dat"
# Detector: L_monitor_I=1.82339e+08 L_monitor_ERR=105494 L_monitor_N=1e+08 "L_monitor.dat"
# INFO: Placing instr file copy test_HBS_thermal_Source_custom.instr in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_HBS_thermal_Source_custom
# INFO: Placing generated c-code copy test_HBS_thermal_Source_custom.c in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_HBS_thermal_Source_custom
#
# ----------------------------------------------------------------------
#
# INFO: Using directory: "/home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_HBS_thermal_Source_custom"
# INFO: Regenerating c-file: test_HBS_thermal_Source_custom.c
# CFLAGS=
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# INFO: Recompiling: ./test_HBS_thermal_Source_custom.out
# INFO: ===
# --------------------------------------------------------------------------
# WARNING: Linux kernel CMA support was requested via the
# btl_vader_single_copy_mechanism MCA variable, but CMA support is
# not available due to restrictive ptrace settings.
#
# The vader shared memory BTL will fall back on another single-copy
# mechanism if one is available. This may result in lower performance.
#
#   Local host: slimbook
# --------------------------------------------------------------------------
# Simulation 'test_HBS_thermal_Source_custom' (test_HBS_thermal_Source_custom.instr): running on 4 nodes (master is 'slimbook', MPI version 3.1).
# Instrument parameters for test_HBS_thermal_Source_custom (test_HBS_thermal_Source_custom.instr)
# [slimbook:27831] 3 more processes have sent help message help-btl-vader.txt / cma-permission-denied
# [slimbook:27831] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# *** TRACE end ***
# Detector: TOF_monitor_I=1.82308e+08 TOF_monitor_ERR=105494 TOF_monitor_N=3.24599e+07 "TOF_monitor.dat"
# Detector: L_monitor_I=1.82339e+08 L_monitor_ERR=105494 L_monitor_N=1e+08 "L_monitor.dat"
# INFO: Placing instr file copy test_HBS_thermal_Source_custom.instr in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_HBS_thermal_Source_custom
# INFO: Placing generated c-code copy test_HBS_thermal_Source_custom.c in dataset /home/pablo/OneDrive/Documents/work/PhD/_data/McStas/Source_custom/_simulations/test_HBS_thermal_Source_custom

# %%
ms.make_sub_plot(data, log = True)
